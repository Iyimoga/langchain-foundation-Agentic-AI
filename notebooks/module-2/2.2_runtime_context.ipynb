# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="groq:llama-3.1-8b-instant",
    context_schema=ColourContext  
)
# Out:
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='5eeb4723-a5fd-45f3-baec-6254e00eebef'),
#               AIMessage(content="Unfortunately, I'm a large language model, I don't have the ability to know your personal preferences or memories. You haven't shared your favorite color with me either. If you'd like to share, I'd be happy to chat with you about it.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 41, 'total_tokens': 94, 'completion_time': 0.078630958, 'completion_tokens_details': None, 'prompt_time': 0.001902631, 'prompt_tokens_details': None, 'queue_time': 0.005392745, 'total_time': 0.080533589}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8639719ff2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd73f-91cf-7293-ac2f-0b9f3a2cbff4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 53, 'total_tokens': 94})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model="groq:llama-3.1-8b-instant",
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='b6a41990-eb0b-4418-93d7-c702f70f3758'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'rwzmmgrmw', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 267, 'total_tokens': 277, 'completion_time': 0.021086716, 'completion_tokens_details': None, 'prompt_time': 0.014725598, 'prompt_tokens_details': None, 'queue_time': 0.037438225, 'total_time': 0.035812314}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_e09ee421cf', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-a9c0-7f63-95e6-6501fa7f1ae7-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'rwzmmgrmw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 10, 'total_tokens': 277}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='a846996e-6406-402e-83b5-9292aed1837d', tool_call_id='rwzmmgrmw'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'th8pepyys', 'function': {'arguments': '{}', 'name': 'get_least_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 289, 'total_tokens': 301, 'completion_time': 0.009138996, 'completion_tokens_details': None, 'prompt_time': 0.019684152, 'prompt_tokens_details': None, 'queue_time': 0.00540007, 'total_time': 0.028823148}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_03e8423237', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-ad10-77f1-b565-dfd34c89d648-0', tool_calls=[{'name': 'get_least_favourite_colour', 'args': {}, 'id': 'th8pepyys', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 12, 'total_tokens': 301}),
#               ToolMessage(content='yellow', name='get_least_favourite_colour', id='f9a6b01a-2730-479d-871d-777095f4173c', tool_call_id='th8pepyys'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '0msfas22w', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}, {'id': 'v8snfx15a', 'function': {'arguments': '{}', 'name': 'get_least_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 312, 'total_tokens': 334, 'completion_time': 0.023695475, 'completion_tokens_details': None, 'prompt_time': 0.019899493, 'prompt_tokens_details': None, 'queue_time': 0.00530075, 'total_time': 0.043594968}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6a1eabf260', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-ae1b-7d11-bb5d-6aab4a2116ce-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '0msfas22w', 'type': 'tool_call'}, {'name': 'get_least_favourite_colour', 'args': {}, 'id': 'v8snfx15a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 312, 'output_tokens': 22, 'total_tokens': 334}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='8e353913-65d4-487c-b2cb-afd16eb05b4d', tool_call_id='0msfas22w'),
#               ToolMessage(content='yellow', name='get_least_favourite_colour', id='51a1b38e-f08b-4339-b17d-2e79fd0fd437', tool_call_id='v8snfx15a'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ek41m6q7t', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}, {'id': 'jxqye44a4', 'function': {'arguments': '{}', 'name': 'get_least_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 352, 'total_tokens': 374, 'completion_time': 0.019337817, 'completion_tokens_details': None, 'prompt_time': 0.019561185, 'prompt_tokens_details': None, 'queue_time': 0.005150396, 'total_time': 0.038899002}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_03e8423237', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-af65-7d72-b9ef-3201754b23d7-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'ek41m6q7t', 'type': 'tool_call'}, {'name': 'get_least_favourite_colour', 'args': {}, 'id': 'jxqye44a4', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 352, 'output_tokens': 22, 'total_tokens': 374}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='79fb72aa-f095-440d-989a-d22d91861fd9', tool_call_id='ek41m6q7t'),
#               ToolMessage(content='yellow', name='get_least_favourite_colour', id='677965b2-1dd4-440b-aea1-964fb68a424e', tool_call_id='jxqye44a4'),
#               AIMessage(content='You are still thinking about your favourite and least favourite colours.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 392, 'total_tokens': 405, 'completion_time': 0.028661651, 'completion_tokens_details': None, 'prompt_time': 0.025451952, 'prompt_tokens_details': None, 'queue_time': 0.005223753, 'total_time': 0.054113603}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6a1eabf260', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-b088-7933-9352-12de5f7eca38-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 392, 'output_tokens': 13, 'total_tokens': 405})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='d251318a-0332-412d-9e8e-14eac2a6c1da'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'rj3t6174h', 'function': {'arguments': '{}', 'name': 'get_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 267, 'total_tokens': 278, 'completion_time': 0.027500916, 'completion_tokens_details': None, 'prompt_time': 0.017349157, 'prompt_tokens_details': None, 'queue_time': 0.012139549, 'total_time': 0.044850073}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6a1eabf260', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-b54c-7931-88d1-ee301a04bba7-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'rj3t6174h', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 267, 'output_tokens': 11, 'total_tokens': 278}),
#               ToolMessage(content='green', name='get_favourite_colour', id='65e0464a-096a-4d18-a63a-029815cd74e9', tool_call_id='rj3t6174h'),
#               AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '9qm81xs8q', 'function': {'arguments': '{}', 'name': 'get_least_favourite_colour'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 289, 'total_tokens': 301, 'completion_time': 0.009653348, 'completion_tokens_details': None, 'prompt_time': 0.019037782, 'prompt_tokens_details': None, 'queue_time': 0.006675203, 'total_time': 0.02869113}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_03e8423237', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-b67b-74c3-8a7c-343cb04295c0-0', tool_calls=[{'name': 'get_least_favourite_colour', 'args': {}, 'id': '9qm81xs8q', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 12, 'total_tokens': 301}),
#               ToolMessage(content='yellow', name='get_least_favourite_colour', id='e6739328-1cb7-4385-b867-b1bf3dca25de', tool_call_id='9qm81xs8q'),
#               AIMessage(content='You can call functions like this to get more information about your favourite colours.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 312, 'total_tokens': 328, 'completion_time': 0.035972821, 'completion_tokens_details': None, 'prompt_time': 0.017291456, 'prompt_tokens_details': None, 'queue_time': 0.039900792, 'total_time': 0.053264277}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_d9492c3c54', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd740-b7bb-7df0-b3d6-1ff4a6057c00-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 312, 'output_tokens': 16, 'total_tokens': 328})]}
