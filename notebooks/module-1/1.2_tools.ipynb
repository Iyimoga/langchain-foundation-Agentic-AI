# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5
# Out:
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="groq:llama-3.3-70b-versatile",
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 225?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 225 is 15.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 225?', additional_kwargs={}, response_metadata={}, id='4519214b-b959-4d28-b031-f3edab4cd399'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '71fr5jxgr', 'function': {'arguments': '{"x":225}', 'name': 'square_root'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 243, 'total_tokens': 257, 'completion_time': 0.047583208, 'completion_tokens_details': None, 'prompt_time': 0.012312373, 'prompt_tokens_details': None, 'queue_time': 0.050552802, 'total_time': 0.059895581}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd32f-01fc-7112-9609-733eecb688ac-0', tool_calls=[{'name': 'square_root', 'args': {'x': 225}, 'id': '71fr5jxgr', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 243, 'output_tokens': 14, 'total_tokens': 257}),
#  ToolMessage(content='15.0', name='square_root', id='c6313d1a-c6d7-44b4-9d2d-5ba53a7f24e6', tool_call_id='71fr5jxgr'),
#  AIMessage(content='The square root of 225 is 15.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 270, 'total_tokens': 281, 'completion_time': 0.019906883, 'completion_tokens_details': None, 'prompt_time': 0.026119067, 'prompt_tokens_details': None, 'queue_time': 0.041799007, 'total_time': 0.04602595}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd32f-0562-73b1-a8d8-1dec5479e854-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 270, 'output_tokens': 11, 'total_tokens': 281})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 225}, 'id': '71fr5jxgr', 'type': 'tool_call'}]
