# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "groq:llama-3.1-8b-instant"
)
# Out:
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Joseph and my favourite colour is Purple")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Joseph and my favourite colour is Purple', additional_kwargs={}, response_metadata={}, id='398a6b59-3909-4832-a2d8-86ff0cf600b2'),
#               AIMessage(content="Nice to meet you, Joseph. Purple is a beautiful colour, often associated with luxury, creativity, and wisdom. It's a unique and vibrant hue that can add a lot of character to any design or setting. Do you have a particular shade of purple that you especially like, or is it more of a general preference for the colour in general?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 46, 'total_tokens': 117, 'completion_time': 0.095065466, 'completion_tokens_details': None, 'prompt_time': 0.002573541, 'prompt_tokens_details': None, 'queue_time': 0.005648776, 'total_time': 0.097639007}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8639719ff2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd341-e63b-77b1-a32e-849da922fed8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 71, 'total_tokens': 117})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='362cbc21-17d3-4165-a6e4-acef5266825d'),
#               AIMessage(content="I don't have any information about your personal preferences, including your favourite colour. I can try to make a guess or ask you some questions to narrow down some possibilities if you'd like.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 41, 'total_tokens': 80, 'completion_time': 0.070065623, 'completion_tokens_details': None, 'prompt_time': 0.003291099, 'prompt_tokens_details': None, 'queue_time': 0.040190392, 'total_time': 0.073356722}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4848f70c04', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd342-a85b-7020-ae3c-6ccff7821ae2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 39, 'total_tokens': 80})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "groq:llama-3.1-8b-instant",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Joseph and my favourite colour is Purple")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Joseph and my favourite colour is Purple', additional_kwargs={}, response_metadata={}, id='35f6e2b8-52eb-4239-9891-2d733b24e508'),
#               AIMessage(content="Hello Joseph, nice to meet you.  It's great that you have a favourite colour, Purple is a beautiful and rich colour. Many people find it to be a very calming and creative colour. Do you have a particular shade of purple that you prefer, or is it just the colour as a whole that you like?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 46, 'total_tokens': 112, 'completion_time': 0.10200526, 'completion_tokens_details': None, 'prompt_time': 0.00214569, 'prompt_tokens_details': None, 'queue_time': 0.038727424, 'total_time': 0.10415095}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4848f70c04', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd343-cc52-7d23-a4be-ecab6b5e003a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 66, 'total_tokens': 112})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Joseph and my favourite colour is Purple', additional_kwargs={}, response_metadata={}, id='35f6e2b8-52eb-4239-9891-2d733b24e508'),
#               AIMessage(content="Hello Joseph, nice to meet you.  It's great that you have a favourite colour, Purple is a beautiful and rich colour. Many people find it to be a very calming and creative colour. Do you have a particular shade of purple that you prefer, or is it just the colour as a whole that you like?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 46, 'total_tokens': 112, 'completion_time': 0.10200526, 'completion_tokens_details': None, 'prompt_time': 0.00214569, 'prompt_tokens_details': None, 'queue_time': 0.038727424, 'total_time': 0.10415095}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4848f70c04', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd343-cc52-7d23-a4be-ecab6b5e003a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 66, 'total_tokens': 112}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='f8c7ec07-bb01-4115-91be-1dc38528747b'),
#               AIMessage(content='Your favourite colour, Joseph, is Purple.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 127, 'total_tokens': 137, 'completion_time': 0.014440004, 'completion_tokens_details': None, 'prompt_time': 0.007210552, 'prompt_tokens_details': None, 'queue_time': 0.038843483, 'total_time': 0.021650556}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4848f70c04', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd344-51ce-7ac2-926e-a1907b2d284b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 127, 'output_tokens': 10, 'total_tokens': 137}),
#               HumanMessage(content="Tell me my name and What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='1cda6acb-bb92-432b-aa2e-fc3fc181cf47'),
#               AIMessage(content='Your name is Joseph, and your favourite colour is Purple.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 157, 'total_tokens': 170, 'completion_time': 0.008823266, 'completion_tokens_details': None, 'prompt_time': 0.008613857, 'prompt_tokens_details': None, 'queue_time': 0.00503126, 'total_time': 0.017437123}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_8639719ff2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd344-f654-7eb0-b308-2ae4f86341d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 157, 'output_tokens': 13, 'total_tokens': 170}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='4c7ef98a-3889-4cda-8aee-7794d422270e'),
#               AIMessage(content='Your favourite colour is Purple.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 185, 'total_tokens': 192, 'completion_time': 0.003730265, 'completion_tokens_details': None, 'prompt_time': 0.010738478, 'prompt_tokens_details': None, 'queue_time': 0.038809212, 'total_time': 0.014468743}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4848f70c04', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fd345-4096-7642-9773-648cdcadf202-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 185, 'output_tokens': 7, 'total_tokens': 192})]}
