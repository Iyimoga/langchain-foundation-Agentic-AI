# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model = "groq:llama-3.3-70b-versatile")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="The Moon is a natural satellite of the Earth and does not have a capital city. The Moon is not a country or a sovereign state, so it does not have a government or administrative centers. It's simply a celestial body that orbits our planet!\n\nIf you're interested in learning more about the Moon or space exploration, I'd be happy to help with that!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 43, 'total_tokens': 117, 'completion_time': 0.241883042, 'completion_tokens_details': None, 'prompt_time': 0.002236842, 'prompt_tokens_details': None, 'queue_time': 0.19389325, 'total_time': 0.244119884}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fcf8a-d1b4-77b3-82e3-44b40525d84c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 74, 'total_tokens': 117})

# %%
print(response.content)
# Out:
# The Moon is a natural satellite of the Earth and does not have a capital city. The Moon is not a country or a sovereign state, so it does not have a government or administrative centers. It's simply a celestial body that orbits our planet!
#
# If you're interested in learning more about the Moon or space exploration, I'd be happy to help with that!

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'logprobs': None,
#  'model_name': 'llama-3.3-70b-versatile',
#  'model_provider': 'groq',
#  'service_tier': 'on_demand',
#  'system_fingerprint': 'fp_43d97c5965',
#  'token_usage': {'completion_time': 0.241883042,
#                  'completion_tokens': 74,
#                  'completion_tokens_details': None,
#                  'prompt_time': 0.002236842,
#                  'prompt_tokens': 43,
#                  'prompt_tokens_details': None,
#                  'queue_time': 0.19389325,
#                  'total_time': 0.244119884,
#                  'total_tokens': 117}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model = "groq:llama-3.3-70b-versatile",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon is a natural satellite, and it doesn't have a capital city. The Moon has no atmosphere, no permanent human residents, and no established government, so it doesn't have a capital in the classical sense. However, there are some interesting lunar landmarks and features, such as the Sea of Tranquility (where the Apollo 11 mission landed) and the lunar south pole. Would you like to know more about the Moon or space exploration?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)
# Out:
# C:\Users\HomePC\Desktop\Langchain_foundation\lca-lc-foundations\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
agent = create_agent(model = "groq:llama-3.3-70b-versatile")

# %%
agent = create_agent("groq:llama-3.3-70b-versatile")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='e5628711-1fb3-4a59-a683-749d5949426d'),
#               AIMessage(content="The Moon is a natural satellite that doesn't have a capital city. It's a celestial body that orbits the Earth, and it doesn't have a government or permanent human settlements. While humans have walked on the Moon as part of NASA's Apollo missions, there are no established cities or capitals on the Moon. Would you like to know more about the Moon or space exploration?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 76, 'prompt_tokens': 43, 'total_tokens': 119, 'completion_time': 0.218995084, 'completion_tokens_details': None, 'prompt_time': 0.00271498, 'prompt_tokens_details': None, 'queue_time': 0.04240311, 'total_time': 0.221710064}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ba38bbab80', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fcf8e-5737-76e2-b188-f5da8ed83484-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 76, 'total_tokens': 119})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon is a natural satellite that doesn't have a capital city. It's a celestial body that orbits the Earth, and it doesn't have a government or permanent human settlements. While humans have walked on the Moon as part of NASA's Apollo missions, there are no established cities or capitals on the Moon. Would you like to know more about the Moon or space exploration?

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='b5c5ddfb-45f0-4c3d-a008-9e6e2955f65e'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='2673db7c-1b7b-4535-8d9a-1c199a6c5fdc', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='239b3f9d-3a2f-4478-a66d-fc390c595a22'),
#               AIMessage(content="There is no such city as Luna City that serves as the capital of the Moon. The Moon is a natural satellite of Earth and does not have a capital city or any permanent human settlements. While there have been several manned missions to the Moon in the past, no human has ever established a permanent residence or government on the Moon.\n\nMy previous response was incorrect, and I apologize for any confusion. If you have any other questions, I'll be happy to help!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 70, 'total_tokens': 164, 'completion_time': 0.31682612, 'completion_tokens_details': None, 'prompt_time': 0.012815377, 'prompt_tokens_details': None, 'queue_time': 0.042122625, 'total_time': 0.329641497}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fcf8f-8efa-77e3-b6d0-d5293a991378-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 70, 'output_tokens': 94, 'total_tokens': 164})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# I'm afraid there's been a mistake! There is no city called Luna City that is the capital of the Moon. In fact, the Moon has no established capital city or permanent human settlements. The Moon is a natural satellite that is devoid of human habitation and infrastructure, except for a few robotic missions and spacecraft that have visited its surface over the years.
#
# However, there have been several proposals and conceptual designs for lunar cities or settlements, often referred to as "Lunar City" or "Moon City," but these are still in the realm of science fiction or theoretical planning.
#
# One notable example is the concept of a lunar city proposed by architect and urban planner, Konstantin Tsiolkovsky, in the early 20th century. Tsiolkovsky envisioned a self-sustaining city on the Moon, powered by solar energy and supported by a reliable food supply, air, and water.
#
# More recently, NASA and other space agencies, as well as private companies, have proposed various concepts for lunar bases or settlements, often with the goal of establishing a sustainable human presence on the Moon. These plans often involve the use of in-situ resource utilization (ISRU), where resources found on the Moon, such as water ice, are used to support human life and propulsion.
#
# While we have not yet established a permanent human settlement on the Moon, there are ongoing efforts to explore the Moon and develop the technologies necessary for a sustainable human presence. Perhaps one day, we will see the establishment of a lunar city, but for now, it remains a topic of fascination and speculation.
#
# Would you like to know more about the possibilities of lunar settlements or the current state of space exploration?
